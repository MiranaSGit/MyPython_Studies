# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
left_hand = set('vxsrtqdgzacbewf')
right_hand = set('umhljikopyn')
word = set(input('Please enter your word : '))
print(not(word.isdisjoint(right_hand) and not(word.isdisjoint(left_hand))))
# Out:
# Please enter your word : tester
# False

# %%
left_hand = {'v', 'x', 's', 'r', 't', 'q', 'd', 'g', 'z', 'a', 'c', 'b', 'e', 'w', 'f'}
right_hand = {'u', 'm', 'h', 'l', 'j', 'i', 'k', 'o', 'p', 'y', 'n'}
word = set(input("Please provide a word for checking whether it is comfortable word or not: "))
print(word)
print(bool((word.intersection(left_hand) and word.intersection(right_hand))))
# Out:
# Please provide a word for checking whether it is comfortable word or not: polly
# {'l', 'p', 'y', 'o'}
# False
