# %%
a = """ 
line1
line2
line3
line4
line5
line6
line7
"""

print(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-a1c213f90535> in <module>()
#       8 line7
#       9 """
# ---> 10 a.readlines()
#      11 print(a)
#
# AttributeError: 'str' object has no attribute 'readlines'
