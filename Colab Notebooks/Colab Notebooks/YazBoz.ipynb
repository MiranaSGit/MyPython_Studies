# %%
righty = set('yuoiphjlknm')
lefty = set('qwerasdftzxcvb')
word = set(input('Please enter your word : '))
a = word.intersection(righty)
b = word.intersection(lefty)
print(word == a and word == b or not word == a and not word == b)

# %%
num = 0
for i in range(1,6):
    str = i*"2"
    num = int(str)
    sum += num
print(sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-e80c0efb7148> in <module>()
#       3     str = i*"2"
#       4     num = int(str)
# ----> 5     sum += num
#       6 print(sum)
#
# TypeError: unsupported operand type(s) for +=: 'builtin_function_or_method' and 'int'

# %%
num = int((input("sayı giriniz: "))
if num == 0:
    print(num, "is zero")
elif num > 0:
    print(num, "is positive")
else:
    print(num, "is negative")
# Out:
#   File "<ipython-input-1-c701258c5416>", line 2
#     if num == 0:
#                ^
# SyntaxError: invalid syntax
