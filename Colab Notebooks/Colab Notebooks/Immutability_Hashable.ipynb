# %% [markdown]
# **Immutable versus Mutable**

# %% [markdown]
# In this study we will focus on:
#
# First, what is immutability
#
# Second, id's of variables
#
# Third, hash values of variables

# %% [markdown]
# **Everything in Python is an object . You have to understand that Python represents all its data as objects. An object’s mutability is determined by its type. Some of these objects like sets, lists and dictionaries are mutable , meaning you can change their content without changing their identity. Other objects like integers, floats, strings and tuples are objects that can not be changed.**

# %% [markdown]
# ![Capture2.PNG](data:image/png;base64,...)

# %% [markdown]
# **Objects of built-in types like (int, float, bool, str, tuple, unicode) are immutable. Objects of built-in types like (list, set, dict) are mutable. Custom classes are generally mutable.**

# %% [markdown]
# ![immutable versus mutable.PNG](data:image/png;base64,...)

# %% [markdown]
# **Immutable objects** are a type of object that cannot be modified after they were created.
#
#  **immutable objects are tuples, strings, integers, and Booleans**. These objects cannot be modified after they were created.
#
# **Hashable objects,** on the other hand, are a type of object that you can call hash() on.

# %% [markdown]
# **Strings are immutable in Python, which means you cannot change an existing string. The best you can do is create a new string that is a variation on the original.**

# %%
text1 = "Aziz"  # text1 is a type of str which has a unique hash value

print(text1)
# Out:
# Aziz

# %%
hash(text1)
# Out:
# 4113450377065593046

# %%
text1 = "Aziz"
text2 = text1  # meaning that text2 has the same value as text2 does. Both the 
               # variables use the same memory location
print(text1)
print(text2)
# Out:
# Aziz
# Aziz

# %%
hash(text2)
# Out:
# 4113450377065593046

# %%
text1 = "Burak" # a new value is now assigned to text1 but this doesn't mean we 
                # have modified it; rather we we assigned it a new value so its
                # hash value changed because of its immutabale feature

hash(text1)
# Out:
# -4506137571982759998

# %%
hash(text2)
# Out:
# 4113450377065593046

# %% [markdown]
# **Identity:**
#
# An object’s identity never changes once it has been created; you may think of it as the object’s address in memory. The is operator compares the identity of two objects; the id() function returns an integer representing its identity.

# %% [markdown]
# **The built-in function id() returns the identity of an object as an integer. This integer usually corresponds to the object’s location in memory, although this is specific to the Python implementation and the platform being used. The is operator compares the identity of two objects.**

# %%
text1 = "Aziz"
# text2 = text1
print(id(text1))
text1='Burak'
print(id(text1))
text2='Aziz'
print(id(text2))
text1=25
print(id(text1))
# Out:
# 139783635555248
# 139783635364592
# 139783635555248
# 93874951073024

# %%
text1 = "Aziz"
# text2 = text1
print(hash(text1))
text1='Burak'
print(hash(text1))
text2='Aziz'
print(hash(text2))
text1=25
print(hash(text1))
# Out:
# 4113450377065593046
# -4506137571982759998
# 4113450377065593046
# 25

# %%
list1=[1,2,3,4,5]
list2=[1,2,3,4,5]
print(id(list1))
print(id(list2))
# Out:
# 139783635511328
# 139783635681920

# %%
list1=[1,2,3,4,5]
list1=[1,2,3,4,5,6]  # this is NOT an assignment, rather modification
print(id(list1))
print(id(list1))
print(list1)
# Out:
# 139783635342592
# 139783635342592
# [1, 2, 3, 4, 5, 6]

# %%
text1 = 25
id(text1)
# Out:
# 93874951073024

# %%
id(text1)
# Out:
# 139783635930608

# %%
id(text1) == id(text2)
# Out:
# True

# %%
id(text1)
# Out:
# 139783635930608

# %%
id(text2)
# Out:
# 139783773261104

# %%
hash(text1) == hash(text2)
# Out:
# True

# %%
text1 = "Burak"

# %%
id(text1)  == id(text2)
# Out:
# False

# %%
id(text1)
# Out:
# 139783773261104

# %%
id(text2)
# Out:
# 139783773261104

# %%
hash(text1) == hash(text2)
# Out:
# False

# %% [markdown]
# **Being an immutable object doesn't allow us to make modification on itself** **meaning that it doesn't communicate with any method for modification**

# %%
text1 = "Aziz"
text1.append(a)  # AttributeError: 'str' object has no attribute 'append'

# %%
text1[0] = "a"  # TypeError: 'str' object does not support item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-1b9c90c3d110> in <module>()
# ----> 1 text1[0] = "a"  # TypeError: 'str' object does not support item assignment
#
# TypeError: 'str' object does not support item assignment

# %%
x = 10
x.append(1)  # AttributeError: 'int' object has no attribute 'append'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-42162e4ca400> in <module>()
#       1 x = 10
# ----> 2 x.append(1)  # AttributeError: 'int' object has no attribute 'append'
#
# AttributeError: 'int' object has no attribute 'append'

# %% [markdown]
# **Once the 10 is created, we cannot change it. We can, however, reassign x—but that doesn’t actually mean to change the 10.**

# %% [markdown]
# # **CAUTION; Immutable objects doesn’t allow modification after creation**

# %%
x = 5
hash(x)
# Out:
# 5

# %%
# hash for integer unchanged
print('Hash for 181 is:', hash(181))

# hash for decimal
print('Hash for 181.23 is:',hash(181.23))

# hash for string
print('Hash for Python is:', hash('Python is excellent'))
# Out:
# Hash for 181 is: 181
# Hash for 181.23 is: 530343892119126197
# Hash for Python is: 2512190144164191747

# %% [markdown]
# ![hashable.PNG](data:image/png;base64,...)

# %% [markdown]
# **Let's look at Tuples now:**

# %%
my_tuple = (10, 20, 30)
print(my_tuple)
id(my_tuple)
# Out:
# (10, 20, 30)
# 140097032165728

# %%
my_tuple = (10, 20, 30)
my_tuple[0] = 40
print(my_tuple)  # TypeError: 'tuple' object does not support item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-397cac9c89cd> in <module>()
#       1 my_tuple = (10, 20, 30)
# ----> 2 my_tuple[0] = 40
#       3 print(my_tuple)  # TypeError: 'tuple' object does not support item assignment
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# **hash() method only works for immutable objects as tuple.**

# %%
hash((1,2,3))
# Out:
# 2528502973977326415

# %%
# tuple of vowels
vowels = ('a', 'e', 'i', 'o', 'u')
print('The hash is:', hash(vowels))
# Out:
# The hash is: -8480359185976470071

# %%
vowels1 = ('a', 'e', 'i', 'o', 'u', [1,2,3])
print('The hash is:', hash(vowels1))  # TypeError: unhashable type: 'list'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-d3787e1e9af9> in <module>()
#       1 vowels1 = ('a', 'e', 'i', 'o', 'u', [1,2,3])
# ----> 2 print('The hash is:', hash(vowels1))  # TypeError: unhashable type: 'list'
#
# TypeError: unhashable type: 'list'

# %%
vowels1 = ('a', 'e', 'i', 'o', 'u', [1,2,3])
vowels1[5] [1] = 6
print(vowels1)
# Out:
# ('a', 'e', 'i', 'o', 'u', [1, 6, 3])

# %% [markdown]
# **Lists and dictionaries are unhashable because we cannot call the hash() method on them. Let’s see some examples.**

# %%
list1 = [1, 2, 3, 4, 5]
hash(list1)  # TypeError: unhashable type: 'list' since list1 is mutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-1c4c972f7dc0> in <module>()
#       1 list1 = [1, 2, 3, 4, 5]
# ----> 2 hash(list1)  # TypeError: unhashable type: 'list' since list1 is mutable
#
# TypeError: unhashable type: 'list'

# %%
hash({1 : "one", 2 : "two",3 : "three"})  # TypeError: unhashable type: 'dict'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-e993e2784c1a> in <module>()
# ----> 1 hash({1 : "one", 2 : "two",3 : "three"})  # TypeError: unhashable type: 'dict'
#
# TypeError: unhashable type: 'dict'

# %% [markdown]
# All immutable objects are hashable, but not all hashable objects are immutable. That’s just a rule, so anytime you see some example immutable object, you know for a fact that it’s hashable, but there are some cases where there are hashable objects that you actually can mutate. Python sets can only include hashable objects.

# %% [markdown]
# **Now Let's focus on Lists**
#
# **By comparing Lists and Tuples after some operations and/or applying for some methods, we can clearly figure out if their id's can change or not.**
#
# **Now, we will try to expand our list and tuple using the += operator. This operation will work for both data types. Let’s see what will happen.**

# %%
list_values = [1, 2, 3]
set_values = (1, 2, 3)
print(list_values)
print(set_values)
print(id(list_values))
print(id(set_values))
print()

list_values += [4, 5, 6]
set_values += (4, 5, 6)
print(list_values)
print(set_values)
print(id(list_values))
print(id(set_values))
# Out:
# [1, 2, 3]
# (1, 2, 3)
# 139783635692352
# 139783702747408
#
# [1, 2, 3, 4, 5, 6]
# (1, 2, 3, 4, 5, 6)
# 139783635692352
# 139783635784768

# %% [markdown]
# **We can see that the list identity is not changed, while the tuple identity is changed. This means that we have expanded (modified) our list, but created (assigned) a completely new tuple. Lists are more memory efficient than tuples.**

# %%
my_list = [10, 20, 30]
print(my_list)
print(id(my_list))
print()
my_list[0] = 40
print(my_list)
print(id(my_list))
# Out:
# [10, 20, 30]
# 139783635692992
#
# [40, 20, 30]
# 139783635692992

# %%
m = list([1, 2, 3])
n = m
print(m)
print(id(m))
print()
print(n)
print(id(n))
# Out:
# [1, 2, 3]
# 140097032435584
#
# [1, 2, 3]
# 140097032435584

# %%
m = list([1, 2, 3])
m.pop()
print(m)
print(id(m))
print()
m.append(5)
print(m)
print(id(m))
# Out:
# [1, 2]
# 140097031902624
#
# [1, 2, 5]
# 140097031902624

# %% [markdown]
# **CONCLUSION:**
#
# **Immutable**: immutable objects are not modified and not changeable. int, float, bool, str, tuple, Unicode, etc ... are immutable. immutable objects are expensive and difficult to change. a tuple is enclosed within the parenthesis and are immutable and can't be changed.
#
# **Mutable**: Mutable objects such as list, set, dict, etc can be modified and are easy to change.
#
# We can figure out the immutability/mutability of an object in Python by checking if we can apply for a modification or a new assignment on itself and its hash value changes
